# %%
import pandas as pd
from sklearn.metrics.pairwise import cosine_similarity
from scipy.sparse import csr_matrix
import openai
from key import OPENAI_API_KEY
import pandas as pd
import numpy as np


# Function to find most similar users
def get_similar_users(user_id, matrix, m):
    if user_id not in matrix.index:
        return []
    sim_users = matrix.loc[user_id].sort_values(ascending=False).iloc[1:m+1].index.tolist()
    return sim_users

def user_filtering_recommendations(dataframe, target_user_id, m, ns):
    """
    Generate movie recommendations for a target user based on user-filtering.

    :param dataframe: A pandas DataFrame containing columns 'user_id', 'movie_id', 'rating', 'movie title'.
    :param target_user_id: The user ID for whom recommendations are to be generated.
    :param m: The number of similar users to consider.
    :param ns: The number of candidate items to recommend.
    :return: A list of candidate movie titles.
    """
    # Create a pivot table
    user_movie_matrix = dataframe.pivot_table(index='user_id', columns='movie_id', values='avg_rating', fill_value=0)
    # Convert to sparse matrix
    sparse_matrix = csr_matrix(user_movie_matrix)
    # Compute Cosine Similarity
    cosine_sim = cosine_similarity(sparse_matrix)
    # Convert to DataFrame
    cosine_sim_df = pd.DataFrame(cosine_sim, index=user_movie_matrix.index, columns=user_movie_matrix.index)
    # Find similar users
    similar_users = get_similar_users(target_user_id, cosine_sim_df, m)
    # Get candidate movie IDs
    candidate_ids = dataframe[dataframe['user_id'].isin(similar_users)]['movie_id'].value_counts().head(ns).index
    # Map IDs to Titles
    candidate_titles = dataframe[dataframe['movie_id'].isin(candidate_ids)]['movie_title'].unique().tolist()
    return candidate_titles

# get recommendations from OpenAI
def rec_from_openai(df, m, n, ns, user_id, temp_1, temp_2, random_seed=42):
    """
    Generate movie recommendations for a target user based on user-filtering.
    Input:
        df: dataframe
        m: number of similar users to consider
        n: number of movies to select from total watched movies of this user
        ns: number of candidate items to recommend
        user_id: target user id
        temp_1: OpenAI prompt template for step 1
        temp_2: OpenAI prompt template for step 2
    Output:
        recommendations: a list of recommended movie titles
        hit_rate: hit rate of recommendations in watched movies
    """

    np.random.seed(random_seed)   

    watched_movies = df[df['user_id'] == user_id]['movie_title'].unique().tolist()
    selected_watched_movies = np.random.choice(watched_movies, min(len(watched_movies), n), replace=False).tolist()
    # combine movie name and genre
    selected_watched_movies_genres = set(df[df['movie_title'].isin(selected_watched_movies)]['genres'].unique().tolist())
    candidate_movies = user_filtering_recommendations(df, target_user_id=user_id, m=m, ns=ns)
    
    Input_1 = temp_1.format(candidate_movies, selected_watched_movies, selected_watched_movies_genres)
    response = openai.ChatCompletion.create(
        model="gpt-3.5-turbo",
        messages= [{ 'role':'user','content' : Input_1}],
        # temperature=0,
        # max_tokens=512,
        # top_p=1,
        # frequency_penalty=0,
        # presence_penalty=0,
        )
    prediction_1 = response.choices[0].message.content

    Input_2 = temp_2.format(candidate_movies, selected_watched_movies, selected_watched_movies_genres, prediction_1)
    response = openai.ChatCompletion.create(
        model="gpt-3.5-turbo",
        messages= [{ 'role':'user','content' : Input_2}],
        # temperature=0,
        # max_tokens=512,
        # top_p=1,
        # frequency_penalty=0,
        # presence_penalty=0,
        )
    prediction_2 = response.choices[0].message.content

    # print(Input_1)
    # print(prediction_1)
    # print(Input_2)
    # print(prediction_2)

    recommendations = []
    for movie in prediction_2.split('\n'):
        split_movie = movie.split('.')
        if len(split_movie) > 1:
            recommendations.append(split_movie[1].strip())
    # hit rate of recommendations in watched movies
    if len(recommendations) == 0:
        hit_rate = 0
    else:
        hit_rate = len(set(recommendations).intersection(set(watched_movies))) / len(recommendations)

    return recommendations, hit_rate

# %%
openai.api_key = OPENAI_API_KEY

df = pd.read_csv('/workspaces/LLM-Recommender-System/data/processed_movie100k.csv')

temp_1 = """
Candidate Set (candidate movies): {}.
The movies I have watched (watched movies): {}.
Their genres are: {}.
Step 1: What features are most important to me when selecting movies (Summarize my preferences briefly)? 
Answer: 
"""

temp_2 = """
Candidate Set (candidate movies): {}.
The movies I have watched (watched movies): {}.
Their genres are: {}.
Step 1: What features are most important to me when selecting movies (Summarize my preferences briefly)? 
Answer: {}.
Step 2: Can you recommend 10 movies from the Candidate Set similar to but not in the selected movies I've watched?.
(Format: Here are the 10 movies recommended for you: [no. a candidate movie])
Answer: 
"""
hit_rates = []
for i in range(1, 101):
    user_id = i
    m = 10
    n = 5
    ns = 20
    recommendations, hit_rate = rec_from_openai(df, m, n, ns, user_id, temp_1, temp_2)
    hit_rates.append(hit_rate)
    print(recommendations)
    print(hit_rate)
    print('='*50)
print(f'Average hit rate: {np.mean(hit_rates)}')
# Out:
# ['Toy Story (1995)', 'Fugitive, The (1993)', 'Jurassic Park (1993)', 'Nightmare Before Christmas, The (1993)', 'Terminator 2: Judgment Day (1991)', 'Silence of the Lambs, The (1991)', 'Fargo (1996)', 'Independence Day (ID4) (1996)', 'Raiders of the Lost Ark (1981)', 'Mars Attacks! (1996)']
# 1.0
# ==================================================
# ['Twelve Monkeys (1995)', 'Dead Man Walking (1995)', 'Star Wars (1977)', 'Fargo (1996)', 'Godfather, The (1972)', 'Return of the Jedi (1983)', 'Jerry Maguire (1996)', 'Men in Black (1997)', 'Contact (1997)', 'Full Monty, The (1997)']
# 0.7
# ==================================================
# []
# 0
# ==================================================
# ["Devil's Own, The (1997)", 'Contact (1997)', 'Event Horizon (1997)', 'Chasing Amy (1997)', 'Starship Troopers (1997)', 'English Patient, The (1996)', 'Scream (1996)', 'Air Force One (1997)', 'In & Out (1997)', 'L']
# 0.6
# ==================================================
# ['Star Wars (1977)', 'Stargate (1994)', 'Blade Runner (1982)', 'Independence Day (ID4) (1996)', 'Fish Called Wanda, A (1988)', 'Empire Strikes Back, The (1980)', 'Princess Bride, The (1987)', 'Raiders of the Lost Ark (1981)', 'Return of the Jedi (1983)', 'Terminator, The (1984)', '']
# 0.8181818181818182
# ==================================================
# []
# 0
# ==================================================
# ['Pulp Fiction (1994)', 'Lion King, The (1994)', 'Maverick (1994)', 'Blade Runner (1982)', 'Wizard of Oz, The (1939)', 'Citizen Kane (1941)', 'Monty Python and the Holy Grail (1974)', 'Amadeus (1984)', 'Bridge on the River Kwai, The (1957)', 'Back to the Future (1985)']
# 1.0
# ==================================================
# ['Please provide more details about the types of movies you enjoy, such as specific genres or themes, and I will be able to provide a more tailored recommendation']
# 0.0
# ==================================================
# ['Toy Story (1995)', 'Star Wars (1977)', 'Return of the Jedi (1983)', 'Kolya (1996)', 'Contact (1997)', 'Full Monty, The (1997)', 'Heat (1995)', 'Leaving Las Vegas (1995)', 'English Patient, The (1996)', 'Scream (1996)']
# 0.4
# ==================================================
# ['Silence of the Lambs, The (1991)', 'Lone Star (1996)', 'Wizard of Oz, The (1939)', '2001: A Space Odyssey (1968)', 'Monty Python and the Holy Grail (1974)', 'Raiders of the Lost Ark (1981)', 'GoodFellas (1990)', 'Psycho (1960)', 'Sting, The (1973)', 'Bridge on the River Kwai, The (1957)']
# 1.0
# ==================================================
# ['Toy Story (1995)', 'Star Wars (1977)', 'Forrest Gump (1994)', 'Four Weddings and a Funeral (1994)', 'Dances with Wolves (1990)', 'Silence of the Lambs, The (1991)', 'Fargo (1996)', 'Truth About Cats & Dogs, The (1996)', '2001: A Space Odyssey (1968)', 'Aliens (1986)']
# 0.8
# ==================================================
# ['Apollo 13 (1995)', 'Lion King, The (1994)', 'Jurassic Park (1993)', 'Dances with Wolves (1990)', 'Silence of the Lambs, The (1991)', 'Independence Day (ID4) (1996)', 'Princess Bride, The (1987)', 'Raiders of the Lost Ark (1981)', 'Return of the Jedi (1983)', 'Groundhog Day (1993)']
# 0.7
# ==================================================
# ['Please provide more details about your preferences in order for me to generate a suitable recommendation']
# 0.0
# ==================================================
# []
# 0
# ==================================================
# ['"Toy Story (1995)"', '"Mr', '"Birdcage, The (1996)"', '"Star Wars (1977)"', '"Fargo (1996)"', '"Independence Day (ID4) (1996)"', '"Return of the Jedi (1983)"', '"Jerry Maguire (1996)"', '"Devil\'s Own, The (1997)"', '"My Best Friend\'s Wedding (1997)"']
# 0.0
# ==================================================
# ['Toy Story (1995)', 'Usual Suspects, The (1995)', 'Apollo 13 (1995)', 'Star Wars (1977)', 'Pulp Fiction (1994)', 'Shawshank Redemption, The (1994)', 'Forrest Gump (1994)', 'Fugitive, The (1993)', 'Jurassic Park (1993)', 'Fargo (1996)']
# 0.8
# ==================================================
# ['Holland\'s Opus (1995)", \'Star Wars (1977)\', \'Fargo (1996)\', \'Truth About Cats & Dogs, The (1996)\', \'Rock, The (1996)\', \'Swingers (1996)\', \'Grosse Pointe Blank (1997)\'']
# 0.0
# ==================================================
# ['Shawshank Redemption, The (1994)', 'Forrest Gump (1994)', 'Four Weddings and a Funeral (1994)', 'Fugitive, The (1993)', 'Silence of the Lambs, The (1991)', 'Citizen Kane (1941)', '2001: A Space Odyssey (1968)', 'Mr', 'Sting, The (1973)', 'Graduate, The (1967)']
# 0.9
# ==================================================
# ['While You Were Sleeping (1995)', 'Four Weddings and a Funeral (1994)', 'Princess Bride, The (1987)', 'Raising Arizona (1987)', "Devil's Own, The (1997)", 'Contact (1997)', 'Full Monty, The (1997)', 'English Patient, The (1996)', 'Scream (1996)', 'Liar Liar (1997)']
# 0.3
# ==================================================
# ['Apollo 13 (1995)', 'Star Wars (1977)', 'Forrest Gump (1994)', 'Lion King, The (1994)', 'Jurassic Park (1993)', 'Star Trek: The Wrath of Khan (1982)', 'Raiders of the Lost Ark (1981)', 'Return of the Jedi (1983)', 'Back to the Future (1985)', 'Indiana Jones and the Last Crusade (1989)']
# 0.7
# ==================================================
# ['Copycat (1995)', 'Twelve Monkeys (1995)', 'Natural Born Killers (1994)', 'Pulp Fiction (1994)', 'Silence of the Lambs, The (1991)', 'Fargo (1996)', 'Psycho (1960)', 'The Shining (1980)', 'Evil Dead II (1987)', 'Cape Fear (1991)']
# 0.9
# ==================================================
# ['Jurassic Park (1993)', 'Blade Runner (1982)', 'Terminator 2: Judgment Day (1991)', 'Independence Day (ID4) (1996)', 'Die Hard (1988)', 'Top Gun (1986)', 'Empire Strikes Back, The (1980)', 'Raiders of the Lost Ark (1981)', 'Return of the Jedi (1983)', 'Blues Brothers, The (1980)']
# 0.9
# ==================================================
# ['Toy Story (1995)', 'Blade Runner (1982)', 'Terminator 2: Judgment Day (1991)', 'Silence of the Lambs, The (1991)', 'Die Hard (1988)', 'Monty Python and the Holy Grail (1974)', 'Empire Strikes Back, The (1980)', 'Princess Bride, The (1987)', 'Raiders of the Lost Ark (1981)', 'Return of the Jedi (1983)']
# 0.9
# ==================================================
# ['Mr', 'Braveheart (1995)', 'Star Wars (1977)', 'Pulp Fiction (1994)', 'Shawshank Redemption, The (1994)', 'Forrest Gump (1994)', 'Fargo (1996)', 'Princess Bride, The (1987)', 'Raiders of the Lost Ark (1981)', 'Amadeus (1984)']
# 0.6
# ==================================================
# ['Star Wars (1977)', 'Terminator 2: Judgment Day (1991)', 'Die Hard (1988)', 'Willy Wonka and the Chocolate Factory (1971)', 'Monty Python and the Holy Grail (1974)', 'Raiders of the Lost Ark (1981)', 'Aliens (1986)', 'Apocalypse Now (1979)', 'Return of the Jedi (1983)', 'Alien (1979)']
# 0.6
# ==================================================
# ['Please provide more information or preferences for a more accurate recommendation']
# 0.0
# ==================================================
# []
# 0
# ==================================================
# ['']
# 0.0
# ==================================================
# []
# 0
# ==================================================
# ['Star Wars (1977)', 'George of the Jungle (1997)', 'Full Monty, The (1997)', 'English Patient, The (1996)', 'Scream (1996)', 'Evita (1996)', 'Liar Liar (1997)', 'Air Force One (1997)', 'In & Out (1997)', "Devil's Advocate, The (1997)"]
# 0.6
# ==================================================
# ['Taxi Driver (1976)', 'Fargo (1996)', 'Godfather, The (1972)', '2001: A Space Odyssey (1968)', 'Monty Python and the Holy Grail (1974)', 'Brazil (1985)', 'Amadeus (1984)', 'Raging Bull (1980)', 'Sting, The (1973)', 'When Harry Met Sally']
# 0.3
# ==================================================
# ['Please provide more information about your preferences or criteria for movie recommendations']
# 0.0
# ==================================================
# ['Contact (1997)', 'George of the Jungle (1997)', 'Starship Troopers (1997)', 'English Patient, The (1996)', 'Scream (1996)', 'Rosewood (1997)', 'Liar Liar (1997)', 'Air Force One (1997)', 'In & Out (1997)', "Dante's Peak (1997)"]
# 0.7
# ==================================================
# ['Could you please provide more details about your movie preferences or any specific genres you are interested in?']
# 0.0
# ==================================================
# ['A']
# 0.0
# ==================================================
# ['18 Boogie Nights (1997), no']
# 0.0
# ==================================================
# ['Braveheart (1995)', 'Stargate (1994)', 'Fugitive, The (1993)', 'Jurassic Park (1993)', 'Terminator 2: Judgment Day (1991)', 'Raiders of the Lost Ark (1981)', 'Aliens (1986)', 'Return of the Jedi (1983)', 'Alien (1979)', 'Terminator, The (1984)']
# 0.9
# ==================================================
# ['Toy Story (1995)', 'Braveheart (1995)', 'Star Wars (1977)', 'Forrest Gump (1994)', 'Lion King, The (1994)', 'Aladdin (1992)', 'Rock, The (1996)', 'Twister (1996)', 'Independence Day (ID4) (1996)', 'Empire Strikes Back, The (1980)']
# 0.6
# ==================================================
# []
# 0
# ==================================================
# []
# 0
# ==================================================
# ['Apollo 13 (1995)', 'Star Wars (1977)', 'Pulp Fiction (1994)', 'Fugitive, The (1993)', 'Blade Runner (1982)', 'Terminator 2: Judgment Day (1991)', 'Dances with Wolves (1990)', 'Silence of the Lambs, The (1991)', 'Fargo (1996)', 'Die Hard (1988)']
# 0.7
# ==================================================
# []
# 0
# ==================================================
# ['Please provide more information or preferences regarding movie selection']
# 0.0
# ==================================================
# ['Die Hard (1988)', 'Willy Wonka and the Chocolate Factory (1971)', 'Monty Python and the Holy Grail (1974)', 'Raiders of the Lost Ark (1981)', 'Aliens (1986)', 'Return of the Jedi (1983)', 'Alien (1979)', 'Amadeus (1984)', 'Back to the Future (1985)', 'Young Frankenstein (1974)']
# 1.0
# ==================================================
# ['Toy Story (1995)', 'Mr', 'Fargo (1996)', 'Truth About Cats & Dogs, The (1996)', 'Rock, The (1996)', 'Twister (1996)', 'Independence Day (ID4) (1996)', 'Willy Wonka and the Chocolate Factory (1971)', 'Return of the Jedi (1983)', 'Ransom (1996)']
# 0.8
# ==================================================
# ['']
# 0.0
# ==================================================
# ["Devil's Own, The (1997)", 'In the Company of Men (1997)', 'Chasing Amy (1997)', 'Full Monty, The (1997)', 'English Patient, The (1996)', 'Scream (1996)', 'Evita (1996)', 'Air Force One (1997)', 'L', "Ulee's Gold (1997)"]
# 0.7
# ==================================================
# ['Blade Runner (1982)', 'Silence of the Lambs, The (1991)', '2001: A Space Odyssey (1968)', 'Aliens (1986)', 'Clockwork Orange, A (1971)', 'Alien (1979)', 'Psycho (1960)', 'Terminator, The (1984)', 'Indiana Jones and the Last Crusade (1989)', 'E']
# 0.5
# ==================================================
# ['Star Wars (1977)', 'Nightmare Before Christmas, The (1993)', 'Terminator 2: Judgment Day (1991)', 'Fargo (1996)', 'Independence Day (ID4) (1996)', 'Fish Called Wanda, A (1988)', 'Monty Python and the Holy Grail (1974)', 'Empire Strikes Back, The (1980)', 'Raiders of the Lost Ark (1981)', 'Return of the Jedi (1983)']
# 0.9
# ==================================================
# ['Postino, Il (1994)', 'Star Wars (1977)', 'Fargo (1996)', 'Lone Star (1996)', 'Bound (1996)', 'Return of the Jedi (1983)', 'Chasing Amy (1997)', 'Heat (1995)', 'Secrets & Lies (1996)', 'Scream (1996)']
# 0.4
# ==================================================
# ['Toy Story (1995)', 'Braveheart (1995)', 'Pulp Fiction (1994)', 'Shawshank Redemption, The (1994)', 'Much Ado About Nothing (1993)', 'Terminator 2: Judgment Day (1991)', 'Wizard of Oz, The (1939)', 'Die Hard (1988)', 'Monty Python and the Holy Grail (1974)', 'Raiders of the Lost Ark (1981)']
# 0.4
# ==================================================
# ['Toy Story (1995)', 'Postino, Il (1994)', 'Mr', 'Star Wars (1977)', 'Fargo (1996)', 'Truth About Cats & Dogs, The (1996)', 'Rock, The (1996)', 'Contact (1997)', 'Leaving Las Vegas (1995)', 'Time to Kill, A (1996)']
# 0.5
# ==================================================
# ['Toy Story (1995)', 'Mr', 'Star Wars (1977)', 'Fargo (1996)', 'Truth About Cats & Dogs, The (1996)', 'Rock, The (1996)', 'Independence Day (ID4) (1996)', 'Willy Wonka and the Chocolate Factory (1971)', 'Return of the Jedi (1983)', 'Star Trek: First Contact (1996)']
# 0.5
# ==================================================
# ['Twelve Monkeys (1995)', 'Star Wars (1977)', 'Rock, The (1996)', 'Independence Day (ID4) (1996)', 'Phenomenon (1996)', 'Return of the Jedi (1983)', 'Jerry Maguire (1996)', 'Men in Black (1997)', 'Contact (1997)', 'Heat (1995)']
# 0.9
# ==================================================
# ['Pulp Fiction (1994)', 'The Fugitive (1993)', 'Terminator 2: Judgment Day (1991)', 'The Rock (1996)', 'Die Hard (1988)', 'Alien (1979)', 'The Terminator (1984)', 'Indiana Jones and the Last Crusade (1989)', 'Star Trek: First Contact (1996)', 'Broken Arrow (1996)']
# 0.2
# ==================================================
# ['Toy Story (1995)', 'Fugitive, The (1993)', 'Terminator 2: Judgment Day (1991)', 'Silence of the Lambs, The (1991)', 'Independence Day (ID4) (1996)', 'Die Hard (1988)', 'Top Gun (1986)', 'Monty Python and the Holy Grail (1974)', 'Empire Strikes Back, The (1980)', 'Princess Bride, The (1987)']
# 1.0
# ==================================================
# ['Toy Story (1995)', 'Twelve Monkeys (1995)', 'Star Wars (1977)', 'Rock, The (1996)', 'Twister (1996)', 'Independence Day (ID4) (1996)', 'Willy Wonka and the Chocolate Factory (1971)', 'Return of the Jedi (1983)', 'Jerry Maguire (1996)', 'Men in Black (1997)']
# 0.9
# ==================================================
# ['Toy Story (1995)', 'Twelve Monkeys (1995)', 'Usual Suspects, The (1995)', 'Star Wars (1977)', 'Blade Runner (1982)', 'Silence of the Lambs, The (1991)', 'Fargo (1996)', 'Willy Wonka and the Chocolate Factory (1971)', 'Monty Python and the Holy Grail (1974)', 'Princess Bride, The (1987)']
# 1.0
# ==================================================
# ['Citizen Kane (1941)', 'Monty Python and the Holy Grail (1974)', 'Empire Strikes Back, The (1980)', 'Raiders of the Lost Ark (1981)', 'Clockwork Orange, A (1971)', 'Apocalypse Now (1979)', 'Return of the Jedi (1983)', 'GoodFellas (1990)', 'Psycho (1960)', 'Blues Brothers, The (1980)']
# 1.0
# ==================================================
# []
# 0
# ==================================================
# ['Full Monty, The (1997)', 'Starship Troopers (1997)', 'English Patient, The (1996)', 'Scream (1996)', 'Evita (1996)', 'Liar Liar (1997)', 'Air Force One (1997)', 'Fly Away Home (1996)', 'Titanic (1997)', 'Murder at 1600 (1997)']
# 0.5
# ==================================================
# ['Toy Story (1995)', 'Shawshank Redemption, The (1994)', 'Fugitive, The (1993)', 'Jurassic Park (1993)', 'Nightmare Before Christmas, The (1993)', 'Terminator 2: Judgment Day (1991)', 'Silence of the Lambs, The (1991)', 'Fargo (1996)', 'Independence Day (ID4) (1996)', 'Wizard of Oz, The (1939)']
# 0.9
# ==================================================
# ['Twelve Monkeys (1995)', 'Birdcage, The (1996)', 'Fargo (1996)', 'Truth About Cats & Dogs, The (1996)', 'Rock, The (1996)', 'Chasing Amy (1997)', 'Grosse Pointe Blank (1997)', 'Men in Black (1997)', 'Contact (1997)', 'Leaving Las Vegas (1995)']
# 0.7
# ==================================================
# ['Silence of the Lambs, The (1991)', 'Fargo (1996)', 'Monty Python and the Holy Grail (1974)', 'Empire Strikes Back, The (1980)', 'Princess Bride, The (1987)', 'Raiders of the Lost Ark (1981)', 'Star Trek: First Contact (1996)', 'Star Trek: The Wrath of Khan (1982)', 'Toy Story (1995)', 'When Harry Met Sally']
# 0.9
# ==================================================
# ['Star Wars (1977)', 'Shawshank Redemption, The (1994)', 'Forrest Gump (1994)', 'Sleepless in Seattle (1993)', 'Dances with Wolves (1990)', 'Silence of the Lambs, The (1991)', 'Twister (1996)', 'Raiders of the Lost Ark (1981)', 'Return of the Jedi (1983)', 'Dead Poets Society (1989)']
# 0.7
# ==================================================
# ['Toy Story (1995)', 'Twelve Monkeys (1995)', 'Mr', 'Star Wars (1977)', 'Fargo (1996)', 'Truth About Cats & Dogs, The (1996)', 'Rock, The (1996)', 'Twister (1996)', 'Independence Day (ID4) (1996)', 'Return of the Jedi (1983)']
# 0.6
# ==================================================
# ['Birdcage, The (1996)', 'Rock, The (1996)', 'Twister (1996)', 'Independence Day (ID4) (1996)', 'Long Kiss Goodnight, The (1996)', 'Willy Wonka and the Chocolate Factory (1971)', 'Mars Attacks! (1996)', 'Jerry Maguire (1996)', 'Leaving Las Vegas (1995)', 'Scream (1996)']
# 0.7
# ==================================================
# ['Twelve Monkeys (1995)', 'Dead Man Walking (1995)', 'Birdcage, The (1996)', 'Fargo (1996)', 'Rock, The (1996)', 'Twister (1996)', 'Independence Day (ID4) (1996)', 'Ghost and the Darkness, The (1996)', 'Men in Black (1997)', 'Ransom (1996)']
# 0.7
# ==================================================
# ['Dead Man Walking (1995)', 'Silence of the Lambs, The (1991)', 'Fargo (1996)', 'Rock, The (1996)', 'Willy Wonka and the Chocolate Factory (1971)', 'Return of the Jedi (1983)', 'Jerry Maguire (1996)', 'Contact (1997)', 'Chasing Amy (1997)', 'Heat (1995)']
# 1.0
# ==================================================
# ['']
# 0.0
# ==================================================
# ['Toy Story (1995)', 'Postino, Il (1994)', 'Star Wars (1977)', 'Silence of the Lambs, The (1991)', 'Fargo (1996)', 'Godfather, The (1972)', 'Princess Bride, The (1987)', 'Brazil (1985)', 'Apocalypse Now (1979)', 'Return of the Jedi (1983)']
# 0.6
# ==================================================
# ['Forrest Gump (1994)', 'Dances with Wolves (1990)', 'Silence of the Lambs, The (1991)', 'Independence Day (ID4) (1996)', 'Wizard of Oz, The (1939)', 'Citizen Kane (1941)', '2001: A Space Odyssey (1968)', 'Top Gun (1986)', 'Empire Strikes Back, The (1980)', 'Blues Brothers, The (1980)']
# 0.8
# ==================================================
# ['Pulp Fiction (1994)', 'Shawshank Redemption, The (1994)', 'Blade Runner (1982)', 'Silence of the Lambs, The (1991)', 'Fargo (1996)', 'Godfather, The (1972)', '2001: A Space Odyssey (1968)', 'Reservoir Dogs (1992)', 'Princess Bride, The (1987)', 'Raiders of the Lost Ark (1981)']
# 0.8
# ==================================================
# ['Twelve Monkeys (1995)', 'Jerry Maguire (1996)', "Devil's Own, The (1997)", 'Full Monty, The (1997)', 'Good Will Hunting (1997)', 'Time to Kill, A (1996)', 'English Patient, The (1996)', 'Liar Liar (1997)', 'Air Force One (1997)', "Devil's Advocate, The (1997)"]
# 0.7
# ==================================================
# ['Twelve Monkeys (1995)', 'Fargo (1996)', 'Rock, The (1996)', 'Twister (1996)', 'Independence Day (ID4) (1996)', 'Star Trek: First Contact (1996)', 'Jerry Maguire (1996)', 'Leaving Las Vegas (1995)', 'Scream (1996)', 'Mission: Impossible (1996)']
# 0.7
# ==================================================
# ['Twelve Monkeys (1995)', 'Seven (Se7en) (1995)', 'Taxi Driver (1976)', 'Star Wars (1977)', 'Pulp Fiction (1994)', 'Shawshank Redemption, The (1994)', 'Blade Runner (1982)', 'Silence of the Lambs, The (1991)', '2001: A Space Odyssey (1968)', 'Empire Strikes Back, The (1980)']
# 0.8
# ==================================================
# ['Please provide more details regarding your preferences for movie selection so that I can provide a more targeted recommendation']
# 0.0
# ==================================================
# ['The only genre mentioned is "unknown," and it is unclear which movies you have enjoyed or disliked from the watched movies list']
# 0.0
# ==================================================
# []
# 0
# ==================================================
# ['Star Wars (1977)', 'Shawshank Redemption, The (1994)', 'Forrest Gump (1994)', 'Fugitive, The (1993)', 'Searching for Bobby Fischer (1993)', 'Dances with Wolves (1990)', 'Fargo (1996)', 'Godfather, The (1972)', 'Citizen Kane (1941)', '2001: A Space Odyssey (1968)']
# 0.5
# ==================================================
# ['Birdcage, The (1996)', 'Fargo (1996)', 'Rock, The (1996)', 'Twister (1996)', 'Independence Day (ID4) (1996)', 'Phenomenon (1996)', 'Long Kiss Goodnight, The (1996)', 'Willy Wonka and the Chocolate Factory (1971)', 'Jerry Maguire (1996)', 'Leaving Las Vegas (1995)']
# 0.8
# ==================================================
# ['Star Wars (1977)', 'Forrest Gump (1994)', 'Fugitive, The (1993)', 'Godfather, The (1972)', 'Wizard of Oz, The (1939)', 'Citizen Kane (1941)', 'Monty Python and the Holy Grail (1974)', 'Raiders of the Lost Ark (1981)', 'Sting, The (1973)', 'Graduate, The (1967)']
# 0.9
# ==================================================
# ['Toy Story (1995)', 'Mr', 'Star Wars (1977)', 'Jurassic Park (1993)', 'Terminator 2: Judgment Day (1991)', 'Twister (1996)', 'Independence Day (ID4) (1996)', 'Willy Wonka and the Chocolate Factory (1971)', 'Top Gun (1986)', 'Empire Strikes Back, The (1980)']
# 0.7
# ==================================================
# ['Twelve Monkeys (1995)', 'Star Wars (1977)', 'Fargo (1996)', 'Truth About Cats & Dogs, The (1996)', 'Rock, The (1996)', 'Twister (1996)', 'Star Trek: First Contact (1996)', 'Men in Black (1997)', 'Liar Liar (1997)', 'Air Force One (1997)']
# 0.7
# ==================================================
# []
# 0
# ==================================================
# ["Devil's Own, The (1997)", 'Contact (1997)', 'Full Monty, The (1997)', 'English Patient, The (1996)', 'Scream (1996)', 'Evita (1996)', 'Liar Liar (1997)', 'L', 'Rainmaker, The (1997)', 'Titanic (1997)']
# 0.5
# ==================================================
# ['Independence Day (ID4) (1996)', 'Godfather, The (1972)', "Monty Python's Life of Brian (1979)", 'Monty Python and the Holy Grail (1974)', 'Empire Strikes Back, The (1980)', 'Raiders of the Lost Ark (1981)', 'Return of the Jedi (1983)', 'Terminator, The (1984)', 'Groundhog Day (1993)', 'Back to the Future (1985)']
# 0.9
# ==================================================
# ['A']
# 0.0
# ==================================================
# ['Birdcage, The (1996)', 'Star Wars (1977)', 'Fargo (1996)', 'Rock, The (1996)', 'Independence Day (ID4) (1996)', 'Phenomenon (1996)', 'Willy Wonka and the Chocolate Factory (1971)', 'Mars Attacks! (1996)', 'Chasing Amy (1997)', 'Full Monty, The (1997)']
# 0.9
# ==================================================
# ['Blade Runner (1982)', 'Silence of the Lambs, The (1991)', 'Fargo (1996)', 'Wizard of Oz, The (1939)', 'Citizen Kane (1941)', 'Mr', 'Cinema Paradiso (1988)', 'Raiders of the Lost Ark (1981)', 'Amadeus (1984)', 'Sting, The (1973)']
# 0.9
# ==================================================
# ['Star Wars (1977)', 'Dances with Wolves (1990)', 'Silence of the Lambs, The (1991)', 'Godfather, The (1972)', 'Wizard of Oz, The (1939)', 'Empire Strikes Back, The (1980)', 'Raiders of the Lost Ark (1981)', 'Return of the Jedi (1983)', 'Alien (1979)', 'Blues Brothers, The (1980)']
# 0.9
# ==================================================
# ['Could you please provide more specific information or preferences?']
# 0.0
# ==================================================
# ['Dead Man Walking (1995)', 'Mr', 'Star Wars (1977)', 'Fargo (1996)', 'Twister (1996)', 'Independence Day (ID4) (1996)', 'Godfather, The (1972)', 'Return of the Jedi (1983)', 'Star Trek: First Contact (1996)', 'Jerry Maguire (1996)']
# 0.3
# ==================================================
# ['']
# 0.0
# ==================================================
# ['Forrest Gump (1994)', 'Fugitive, The (1993)', 'Jurassic Park (1993)', 'Silence of the Lambs, The (1991)', 'Wizard of Oz, The (1939)', 'Sound of Music, The (1965)', 'Raiders of the Lost Ark (1981)', 'Star Trek VI: The Undiscovered Country (1991)', 'Jaws (1975)', "One Flew Over the Cuckoo's Nest (1975)"]
# 1.0
# ==================================================
# ['Blade Runner (1982)', 'Silence of the Lambs, The (1991)', 'Fargo (1996)', 'Godfather, The (1972)', 'Die Hard (1988)', 'Monty Python and the Holy Grail (1974)', 'Empire Strikes Back, The (1980)', 'Princess Bride, The (1987)', 'Brazil (1985)', 'Raising Arizona (1987)']
# 0.7
# ==================================================
# ['Forrest Gump (1994)', 'Blade Runner (1982)', 'Terminator 2: Judgment Day (1991)', 'Die Hard (1988)', 'Monty Python and the Holy Grail (1974)', 'Raiders of the Lost Ark (1981)', 'Aliens (1986)', 'Return of the Jedi (1983)', 'Alien (1979)', 'Terminator, The (1984)']
# 0.7
# ==================================================
# ['Star Wars (1977)', 'Pulp Fiction (1994)', 'Four Weddings and a Funeral (1994)', 'Sleepless in Seattle (1993)', 'Fish Called Wanda, A (1988)', 'Monty Python and the Holy Grail (1974)', 'Blues Brothers, The (1980)', 'Groundhog Day (1993)', 'Back to the Future (1985)', 'Indiana Jones and the Last Crusade (1989)']
# 0.4
# ==================================================
# ['Toy Story (1995)', 'Twelve Monkeys (1995)', 'Star Wars (1977)', 'Rock, The (1996)', 'Return of the Jedi (1983)', 'Men in Black (1997)', 'Contact (1997)', 'Chasing Amy (1997)', 'Leaving Las Vegas (1995)', 'Time to Kill, A (1996)']
# 0.9
# ==================================================
# ['']
# 0.0
# ==================================================
# Average hit rate: 0.5091818181818182
